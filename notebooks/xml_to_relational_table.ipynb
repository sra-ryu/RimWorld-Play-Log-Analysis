# %% [markdown]
# ## XML to relational table
#
# Extract colonist data into two normalized DataFrames:
# - **pawns_df** — one row per colonist (`pawn_id`, `first`, `last`)
# - **skills_df** — one row per skill entry (`pawn_id`, `skill`, `level`)

# %%
import xml.etree.ElementTree as ET
import pandas as pd

tree = ET.parse("../logs/09_04_2026.rws")
root = tree.getroot()

# %% [markdown]
# ### 1. Build the `pawns` table
# - One row per colonist.
# - Columns: `pawn_id` (auto-assigned integer), `first`, `last`.
#
# - Use the same XPath from exercise 11 to get the colonist list
# - `pawn_id` must be assigned manually — there's a built-in that gives you both the index and value while iterating
# - use the method that safely returns `None` when the tag is missing (instead of `.find().text`)
# - Build a dict per row, collect them in a list, then pass to `pd.DataFrame()`

# %%
things = root.find("game/maps/li/things")

pawn_list = []

pawns = things.findall(".//thing[@Class='Pawn'][kindDef='Colonist']")
for pawn_id, pawn in enumerate(pawns):
    pawn_list.append({
        'pawn_id': pawn_id,
        'first': pawn.findtext('name/first'),
        'last': pawn.findtext('name/last')
    })

pawns_df = pd.DataFrame(pawn_list)

print(pawns_df)
# Out:
#     pawn_id first   last
# 0         0    티코   크레이그
# 1         1   나나미  커즈이스크
# 2         2   앤소니   크레이그
# 3         3    콜린  하이드로넷
# 4         4   다프네  하이드로넷
# 5         5  루드밀라     피셔
# 6         6   히스인   라우이트
# 7         7   헤스크  커즈이스크
# 8         8  베네딕트     노턴
# 9         9   마나부  하이드로넷
# 10       10  히스이스   윈'하욘
# 11       11   마룰로  하이드로넷
# 12       12   피노보    호네본
# 13       13   이리나   크레이그
# 14       14  그레이시   플로레스
# 15       15  그레고리  하이드로넷

# %% [markdown]
# ### 2. Build the `skills` table
# - One row per skill per colonist.
# - Columns: `pawn_id`, `skill`, `level`.
# - Skills omitted from XML mean level 0 — fill them in explicitly.
# - Build a `{skill_name: level}` dict from each pawn's XML entries — it makes filling in missing skills straightforward
# - Assign `pawn_id` the same way as in exercise 1 so the two tables can be `merge` later

# %%
ALL_SKILLS = [
    "Shooting", "Melee", "Construction", "Mining", "Cooking", 
    "Plants", "Animals", "Crafting", "Artistic", "Medicine",
    "Social", "Intellectual"
]

things = root.find("game/maps/li/things")
pawns = things.findall(".//thing[@Class='Pawn'][kindDef='Colonist']")

skill_list = []

for pawn_id, pawn in enumerate(pawns):
    skills = {
        skill.findtext('def'): skill.findtext('level') or 0
        for skill in pawn.findall("skills/skills/li")
    }

    for skill_name in ALL_SKILLS:
        skill_list.append({
            'pawn_id': pawn_id,
            'skill': skill_name,
            'level': skills.get(skill_name, 0)
        })

skills_df = pd.DataFrame(skill_list)
print(skills_df)
# Out:
#      pawn_id         skill level
# 0          0      Shooting     8
# 1          0         Melee     1
# 2          0  Construction     1
# 3          0        Mining     6
# 4          0       Cooking     8
# ..       ...           ...   ...
# 187       15      Crafting     0
# 188       15      Artistic     0
# 189       15      Medicine     0
# 190       15        Social     0
# 191       15  Intellectual     0
#
# [192 rows x 3 columns]

# %% [markdown]
# ### 3. Merge two tables
# - Merge two tables(pawn list and skill list) based on `pawn_id`

# %%
merged_df = pd.merge(pawns_df, skills_df, on='pawn_id', how='inner')
merged_df['level'] = merged_df['level'].astype(int)

print(merged_df)
# Out:
#      pawn_id first   last         skill  level
# 0          0    티코   크레이그      Shooting      8
# 1          0    티코   크레이그         Melee      1
# 2          0    티코   크레이그  Construction      1
# 3          0    티코   크레이그        Mining      6
# 4          0    티코   크레이그       Cooking      8
# ..       ...   ...    ...           ...    ...
# 187       15  그레고리  하이드로넷      Crafting      0
# 188       15  그레고리  하이드로넷      Artistic      0
# 189       15  그레고리  하이드로넷      Medicine      0
# 190       15  그레고리  하이드로넷        Social      0
# 191       15  그레고리  하이드로넷  Intellectual      0
#
# [192 rows x 5 columns]

# %% [markdown]
# ### 4. Build a pivot table
# - Reshape `merged_df` so each row is a colonist and each column is a skill.
# - The values should be the skill `level`.
# - Use `pd.pivot_table()` or the DataFrame `.pivot()` method
# - Use `first` (first name) as the row index

# %%
pivot_df = merged_df.pivot(index='first', columns='skill', values='level')
pivot_df = pivot_df.astype(int)

pivot_df
# Out:
# skill  Animals  Artistic  Construction  Cooking  Crafting  Intellectual  \
# first
# 그레고리         0         0             0        0         0             0
# 그레이시        11         1             2        3         1             2
# 나나미          2         6            15       12        13             2
# 다프네          1         1            14        5         3             1
# 루드밀라        10         1             1       14         2             1
# 마나부          5         0             1       14         4             0
# 마룰로          5         1             2        3         0             4
# 베네딕트         2         0             0        2        11             1
# 앤소니          5         0             1       12         1             1
# 이리나          4         3             0        6         4            16
# 콜린           2         0             0        2         1             0
# 티코           1         3             1        8        16            15
# 피노보          2         2             1        2         5             1
# 헤스크          3        10            17        0         0             2
# 히스이스         2        14             5        0         3             3
# 히스인          3         2             1        1         2             0
#
# skill  Medicine  Melee  Mining  Plants  Shooting  Social
# first
# 그레고리          0      0       0       0         0       0
# 그레이시          2      3       6      15        13      13
# 나나미           0      8      12      11         4       2
# 다프네           3      8       4       3         7       6
# 루드밀라         11      2       5      11         0       8
# 마나부           2      7      14       8         0       4
# 마룰로           3     13       2      14         5       1
# 베네딕트          7      8       1       2         4       7
# 앤소니           0      4       1       3        11       9
# 이리나          15      3       6      12        13      11
# 콜린            0      3       2       1         5       2
# 티코            4      1       6       9         8       7
# 피노보          13     11       0      12         4       6
# 헤스크           1      7       8       7        14       2
# 히스이스          0      5       3       3         0       0
# 히스인           3      4       2      10        10       7

# %% [markdown]
# ### 5. Draw a skill heatmap
# - Visualize the pivot table as a heatmap using `matplotlib`.
# - Use `plt.imshow()` to render the 2D array — pass the pivot table's `.values`
# - Set the X-axis ticks to skill names (`pivot_df.columns`) and Y-axis ticks to colonist names (`pivot_df.index`)
# - Add a colorbar with `plt.colorbar()` so the level scale is visible
# - Rotate X-axis labels 45° for readability: `plt.xticks(rotation=45, ha='right')`
# - Give the plot a title and call `plt.tight_layout()` before `plt.show()`

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False

plt.imshow(pivot_df.values)

plt.xticks(range(len(pivot_df.columns)), pivot_df.columns, rotation=45, ha='right')
plt.yticks(range(len(pivot_df.index)), pivot_df.index)

plt.title("Skill Heatmap")
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Find the best colonist per skill
# - For each skill, find the colonist with the highest level.
# - Print the result as a clean table with columns: `skill`, `best_colonist`, `level`.
# - `groupby` + `idxmax()` is one approach: find the row index of the max level per skill, then use `.loc[]` to retrieve the full row
# - Filter out skills where every colonist is level 0 (no one has that skill)
# - Sort the final result by `level` descending

# %%
idx = merged_df.groupby('skill')['level'].idxmax()
best_colonist = merged_df.loc[idx]
best_colonist = best_colonist[best_colonist['level'] > 0].sort_values('level', ascending=False)

print(best_colonist[['skill', 'first', 'level']].rename(columns=({'first': 'best_colonist'})))
# Out:
#             skill best_colonist  level
# 86   Construction           헤스크     17
# 7        Crafting            티코     16
# 167  Intellectual           이리나     16
# 165      Medicine           이리나     15
# 173        Plants          그레이시     15
# 128      Artistic          히스이스     14
# 64        Cooking          루드밀라     14
# 111        Mining           마나부     14
# 84       Shooting           헤스크     14
# 133         Melee           마룰로     13
# 178        Social          그레이시     13
# 174       Animals          그레이시     11

# %% [markdown]
# ### 7. Calculate the average skill levels of colonists
# - Calculate the average level of each skill.
# - Use `.mean()` to calculate average.

# %%
avg_skills = merged_df.groupby('skill')['level'].mean()
print(avg_skills)
# Out:
# skill
# Animals         3.6250
# Artistic        2.7500
# Construction    3.8125
# Cooking         5.2500
# Crafting        4.1250
# Intellectual    3.0625
# Medicine        4.0000
# Melee           5.4375
# Mining          4.5000
# Plants          7.5625
# Shooting        6.1250
# Social          5.3125
# Name: level, dtype: float64

# %% [markdown]
# ### 8. Build the `traits` table
#
# - Columns: `pawn_id`, `first`, `last`, `trait`, `degree`
# - If degree is `None`, it should be 0.

# %%
things = root.find("game/maps/li/things")

pawns = things.findall(".//thing[@Class='Pawn'][kindDef='Colonist']")

traits_list = []

for pawn_id, pawn in enumerate(pawns):
    first = pawn.findtext('name/first')
    last = pawn.findtext('name/last')

    traits = pawn.findall("story/traits/allTraits/li")
    if traits:
        for trait in traits:
            traits_list.append({
                'pawn_id': pawn_id,
                'first': first,
                'last': last,
                'trait': trait.findtext('def'),
                'degree': int(trait.findtext('degree') or 0)
            })
    else:
        traits_list.append({
            'pawn_id': pawn_id,
            'first': first,
            'last': last,
            'trait': "None",
            'degree': 0
        })

traits_df = pd.DataFrame(traits_list)
traits_df
# Out:
#     pawn_id first   last               trait  degree
# 0         0    티코   크레이그              Greedy       0
# 1         0    티코   크레이그            Gourmand       0
# 2         0    티코   크레이그            NightOwl       0
# 3         1   나나미  커즈이스크                Kind       0
# 4         1   나나미  커즈이스크     Industriousness       2
# 5         2   앤소니   크레이그           Masochist       0
# 6         2   앤소니   크레이그              Nimble       0
# 7         2   앤소니   크레이그            NightOwl       0
# 8         3    콜린  하이드로넷                Kind       0
# 9         4   다프네  하이드로넷                Kind       0
# 10        4   다프네  하이드로넷     Industriousness       1
# 11        4   다프네  하이드로넷               Tough       0
# 12        5  루드밀라     피셔            NightOwl       0
# 13        6   히스인   라우이트       Transhumanist       0
# 14        6   히스인   라우이트           Masochist       0
# 15        6   히스인   라우이트  PsychicSensitivity      -1
# 16        7   헤스크  커즈이스크                Kind       0
# 17        7   헤스크  커즈이스크       DislikesWomen       0
# 18        8  베네딕트     노턴         SpeedOffset       2
# 19        8  베네딕트     노턴         NaturalMood       2
# 20        8  베네딕트     노턴               Tough       0
# 21        9   마나부  하이드로넷       Undergrounder       0
# 22       10  히스이스   윈'하욘            NightOwl       0
# 23       10  히스이스   윈'하욘  PsychicSensitivity      -1
# 24       11   마룰로  하이드로넷              Nerves       2
# 25       12   피노보    호네본                Kind       0
# 26       12   피노보    호네본            NightOwl       0
# 27       13   이리나   크레이그                Kind       0
# 28       13   이리나   크레이그         NaturalMood       1
# 29       13   이리나   크레이그       Transhumanist       0
# 30       14  그레이시   플로레스                Kind       0
# 31       14  그레이시   플로레스            Immunity       1
# 32       15  그레고리  하이드로넷                None       0
